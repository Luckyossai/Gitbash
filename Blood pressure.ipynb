# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
data=pd.read_csv('Blood pressure dataset.csv')
data
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
x=data.fillna(1)
x
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %%
dataset=x

# %%
dataset.drop(columns=['Chronic_kidney_disease','alcohol_consumption_per_day'])
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %% [markdown]
# rename

# %%
plt.figure(figsize=(7,7))
plt.bar(dataset['Age'],dataset['Pregnancy'])
# Out:
# <BarContainer object of 2000 artists>

# %%
len(dataset)
# Out:
# 2000

# %%
len(dataset.columns)
# Out:
# 16

# %%
dataset.describe().T
# Out:
#                                 count          mean           std    min  \
# Patient_Number                 2000.0   1000.500000    577.494589    1.0
# Blood_Pressure_Abnormality     2000.0      0.493500      0.500083    0.0
# Level_of_Hemoglobin            2000.0     11.710035      2.186701    8.1
# Genetic_Pedigree_Coefficient   2000.0      0.518055      0.303971    0.0
# Age                            2000.0     46.558500     17.107832   18.0
# BMI                            2000.0     30.081500     11.761208   10.0
# Sex                            2000.0      0.496000      0.500109    0.0
# Pregnancy                      2000.0      0.878500      0.326789    0.0
# Smoking                        2000.0      0.509500      0.500035    0.0
# Physical_activity              2000.0  25254.424500  14015.439623  628.0
# salt_content_in_the_diet       2000.0  24926.097000  14211.692586   22.0
# alcohol_consumption_per_day    2000.0    220.757500    157.444886    0.0
# ...
